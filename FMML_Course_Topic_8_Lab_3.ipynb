# %% [markdown]
# <a href="https://colab.research.google.com/github/Lalitha443322/FMML_LABS_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 13:02:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   212MB/s    in 0.3s
#
# 2024-03-29 13:02:38 (212 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22826  1707.09724v1  Transfer learning aims to improve learning in ...  stat
# 20951  1705.08509v1  The explosive growth of the location-enabled d...    cs
# 211    1504.00641v1  A grand challenge in machine learning is the d...  stat
# 13452   0810.3356v1  Skepticism of the building block hypothesis (B...    cs
# 3620   1802.09841v1  We propose a new active learning strategy desi...    cs
# ...             ...                                                ...   ...
# 1793   1610.04658v2  We consider multi-class classification where t...  stat
# 34581  1704.05091v1  This paper presents the approach developed at ...    cs
# 2823   1802.03471v1  Adversarial examples in machine learning has b...  stat
# 6116   1607.06988v1  Interactive learning is a process in which a m...    cs
# 11905  1703.09772v1  Automatic Music Transcription (AMT) consists i...  stat
#
#                                                    title  year  \
# 22826                 Transfer Learning with Label Noise  2017
# 20951  Predictive Analytics for Enhancing Travel Time...  2017
# 211              A Probabilistic Theory of Deep Learning  2015
# 13452  The Fundamental Problem with the Building Bloc...  2008
# 3620   Adversarial Active Learning for Deep Networks:...  2018
# ...                                                  ...   ...
# 1793   Simultaneous Learning of Trees and Representat...  2016
# 34581  FEUP at SemEval-2017 Task 5: Predicting Sentim...  2017
# 2823   On the Connection between Differential Privacy...  2018
# 6116     Interactive Learning from Multiple Noisy Labels  2016
# 11905  Particle Filtering for PLCA model with Applica...  2017
#
#                                                 keywords
# 22826  [borrowing, knowledge, different, sufficient, ...
# 20951  [explosive, increasing, increasing, awareness,...
# 211    [challenge, development, computational, algori...
# 13452  [skepticism, hypothesis, previously, expressed...
# 3620   [annotation, strategies, uncertain, selection,...
# ...                                                  ...
# 1793   [classification, predictor, hierarchical, stru...
# 34581  [developed, engineering, university, participa...
# 2823   [adversarial, developed, heuristic, approaches...
# 6116   [interactive, algorithm, meaningful, supervise...
# 11905  [automatic, transcription, automatically, esti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22826    [borrowing, knowledge, different, sufficient, ...
# 20951    [explosive, increasing, increasing, awareness,...
# 211      [challenge, development, computational, algori...
# 13452    [skepticism, hypothesis, previously, expressed...
# 3620     [annotation, strategies, uncertain, selection,...
#                                ...
# 11149    [efficient, algorithms, asymmetric, transforma...
# 8345     [performance, accordingly, emergence, tremendo...
# 28446    [introduce, synthesis, convolutional, independ...
# 18995    [abductive, probabilistic, recognition, recogn...
# 22150    [formalized, sequential, simulators, computati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8638 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f551b86d-c529-4c75-abfe-366c87949ac7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f551b86d-c529-4c75-abfe-366c87949ac7")) {                    Plotly.newPlot(                        "f551b86d-c529-4c75-abfe-366c87949ac7",                        [{"x":["representations","simultaneously","knowledge","distribution","covariate","experimental","estimates","borrowing","scenarios","synthetic","sufficient","distributions","exploring","representation","effectiveness","different","invariant","applications","transportation","increasing","crossings","illustrate","explosive","analytics","navigation","evaluates","microsoft","calculate","available","pedestrian","enhancing","geospatial","exemplify","awareness","operating","predictive","estimation","importance","smartphone","individuals","information","routinely","pronunciation","probabilistic","capabilities","challenge","architectures","complicated","understanding","inference","intuitions","development","analyzing","generative","recognition","developing","improvement","computational","shortcomings","providing","principled","orientation","rendering","perceptual","convolutional","synthesizing","outperform","algorithms","variation","explicitly","fundamental","framework","discriminative","successes","extraordinary","previously","theoretical","empirical","assumptions","algorithm","foundations","appraisal","expressed","anomalies","designers","hypothesis","specifically","annotation","demonstrate","approximate","intractable","measuring","uncertain","strategies","convergence","selection","boundaries","considerably","empirically","adversarial","annotations","wikipedia","classifier","typically","ambiguity","resources","instances","supervised","necessary","dictionary","including","statistics","differences","evaluating","disambiguation","automatically","specially","ubiquitous","experiments","components","exploration","interoperability","fingerprint","resolution","complementary","reflection","performance","acquisition","involving","detection","particular","facilitate","community","grayscale","resistant","technique","frustrated","techniques","propagation","architecture","estimating","multiclass","classification","particularly","modifying","generalize","conditions","functions","minimization","robustness","inherently","alternate","properties","widespread","potential","artificial","probability","intelligence","contextual","clustering","dimensional","mentioned","spatiotemporal","associated","organizing","perspective","approximation","computing","numerical","corresponding","visualization","application","similarly","nonparametric","classical","interpret","continuous","expression","hierarchical","relationship","locations","variations","benchmark","nontrivial","measurements","attention","attracted","significant","furthermore","parameter","databases","implicitly","appearance","structure","automatic","evaluated","objectives","adaptation","transferred","disentangles"],"y":[223,107,349,244,2,377,52,2,100,158,74,113,32,373,196,770,59,460,18,112,2,77,5,14,26,7,9,18,322,17,15,3,4,10,19,50,187,103,6,32,685,4,3,160,50,165,132,28,151,228,4,119,65,120,373,63,145,279,7,96,32,25,16,22,408,9,108,616,63,81,87,592,87,8,3,91,173,158,72,825,17,2,31,11,3,43,175,47,562,108,27,21,33,93,129,177,43,30,77,125,55,14,154,108,19,64,102,200,70,52,250,62,58,50,13,174,10,21,599,110,60,3,10,141,37,3,886,40,46,358,262,38,63,10,3,272,2,403,84,257,65,8,510,92,12,56,120,205,69,119,21,5,221,15,155,158,168,98,43,143,175,14,11,108,16,65,123,136,72,130,32,261,15,15,98,21,113,43,110,79,36,67,204,11,43,177,29,231,165,140,62,17,67,342,184,144,29,72,13,3],"type":"bar"},{"x":["representations","simultaneously","knowledge","distribution","covariat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Model</span> <span style=''>of</span> <span style=''>Free</span> <span style=''>Will</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.46296296296296285);'>Artificial</span> <span style=''>Entities</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impression</span> <span style=''>of</span> <span style=''>free</span> <span style=''>will</span> <span style=''>is</span> <span style=''>the</span> <span style=''>feeling</span> <span style='background-color:rgba(0, 255, 0, 0.4027777777777778);'>according</span> <span style=''>to</span> <span style=''>which</span> <span style=''>our</span> <span style=''>choices</span> <span style=''>are</span> <span style=''>neither</span> <span style=''>imposed</span> <span style=''>from</span> <span style=''>our</span> <span style=''>inside</span> <span style=''>nor</span> <span style=''>from</span> <span style=''>outside</span> <span style=''>It</span> <span style=''>is</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>we</span> <span style=''>are</span> <span style=''>the</span> <span style=''>ultimate</span> <span style=''>cause</span> <span style=''>of</span> <span style=''>our</span> <span style=''>acts</span> <span style=''>In</span> <span style=''>direct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>opposition</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>determinism</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>free</span> <span style=''>will</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>continues</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>discussed</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>free</span> <span style=''>will</span> <span style=''>is</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decisional</span> <span style='background-color:rgba(0, 255, 0, 0.40939597315436244);'>mechanism</span> <span style=''>an</span> <span style=''>agent</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>with</span> <span style=''>free</span> <span style=''>will</span> <span style=''>if</span> <span style=''>having</span> <span style='background-color:rgba(0, 255, 0, 0.3551912568306011);'>performed</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>predictable</span> <span style=''>choice</span> <span style=''>Cp</span> <span style=''>it</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>immediately</span> <span style=''>perform</span> <span style=''>another</span> <span style=''>choice</span> <span style=''>Cr</span> <span style=''>in</span> <span style=''>a</span> <span style=''>random</span> <span style=''>way</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>intangible</span> <span style=''>feeling</span> <span style=''>of</span> <span style=''>free</span> <span style=''>will</span> <span style=''>is</span> <span style=''>replaced</span> <span style=''>by</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>predictable</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>immediate ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>and</span> <span style=''>Parallel</span> <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Effective</span> <span style=''>and</span> <span style=''>accurate</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>required</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>stored</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>on</span> <span style=''>one</span> <span style=''>machine</span> <span style=''>Another</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>one</span> <span style=''>may</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encounter</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>contaminations</span> <span style=''>that</span> <span style=''>damage</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>The</span> <span style=''>parallel</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>strategy</span> <span style=''>divides</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>data</span> <span style=''>set</span> <span style=''>into</span> <span style=''>roughly</span> <span style=''>equal</span> <span style=''>subsets</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>on</span> <span style=''>each</span> <span style=''>subset</span> <span style=''>After</span> <span style=''>local</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>this</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>or</span> <span style=''>other</span> <span style=''>modelvariable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>final</span> <span style=''>model</span> <span style=''>by</span> <span style=''>using ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>preconditioning</span> <span style=''>approach</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>preconditioning</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>the</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>metric</span> <span style=''>or</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>exploits</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>and</span> <span style=''>takes</span> <span style=''>into</span> <span style=''>account</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>symmetry</span> <span style=''>that</span> <span style=''>exists</span> <span style=''>in</span> <span style=''>Tucker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>The</span> <span style=''>specific</span> <span style=''>metric</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>versatile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>on</span> <span style=''>quotient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manifolds</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>preconditioned</span> <span style='background-color:rgba(255, 0, 0, 0.38728323699421974);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3125);'>conjugate</span> <span style=''>gradient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>batch</span> <span style=''>and</span> <span style=''>online</span> <span style=''>setups</span> <span style='background-color:rgba(0, 255, 0, 0.513888888888889);'>respectively</span> <span style=''>Concrete</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3639143730886851);'>representations</span> <span style=''>of</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ingredients</span> <span style=''>are</span> <span style=''>listed</span> <span style='background-color:rgba(255, 0, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Revisiting</span> <span style=''>Multiple</span> <span style=''>Instance</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Recently</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style=''>topics</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Artificial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Intelligence</span> <span style=''>related</span> <span style=''>research</span> <span style=''>fields</span> <span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>achieved</span> <span style=''>great</span> <span style=''>success</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>learning</span> <span style=''>as</span> <span style=''>a</span> <span style=''>typical</span> <span style=''>weakly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>for</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biometrics</span> <span style=''>nature</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>etc</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>solving</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>using</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Neural</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appealing</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>perform</span> <span style=''>multiple</span> <span style=''>instance</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>way</span> <span style=''>which</span> <span style=''>take</span> <span style=''>a</span> <span style=''>bag</span> <span style=''>with</span> <span style=''>various</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>as</span> <span style=''>input</span> <span style=''>and</span> <span style=''>directly</span> <span style=''>output</span> <span style=''>bag</span> <span style=''>label</span> <span style=''>All</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>a</span> <span style=''>multiple</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12622061482820976)
# 	segmentation (0.07341772151898734)
# 	experimental (0.13634719710669077)
# 	representation (0.1349005424954792)
# 	architecture (0.09294755877034358)
# 	information (0.24773960216998192)
# 	detection (0.1294755877034358)
# 	different (0.27848101265822783)
# 	recognition (0.1349005424954792)
# 	convolutional (0.14755877034358048)
#
# Some Statistics words are:
# 	variational (0.09336609336609336)
# 	stochastic (0.1262899262899263)
# 	algorithm (0.3759213759213759)
# 	distribution (0.1705159705159705)
# 	theoretical (0.14594594594594595)
# 	statistical (0.14889434889434888)
# 	estimation (0.17788697788697788)
# 	inference (0.20245700245700246)
# 	dimensional (0.1886977886977887)
# 	regression (0.1705159705159705)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7afa179b-244e-49f4-b995-adb5f5a19d93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7afa179b-244e-49f4-b995-adb5f5a19d93")) {                    Plotly.newPlot(                        "7afa179b-244e-49f4-b995-adb5f5a19d93",                        [{"x":["representations","simultaneously","knowledge","distribution","covariate","experimental","estimates","borrowing","scenarios","synthetic","sufficient","distributions","exploring","representation","effectiveness","different","invariant","applications","transportation","increasing","crossings","illustrate","explosive","analytics","navigation","evaluates","microsoft","calculate","available","pedestrian","enhancing","geospatial","exemplify","awareness","operating","predictive","estimation","importance","smartphone","individuals","information","routinely","pronunciation","probabilistic","capabilities","challenge","architectures","complicated","understanding","inference","intuitions","development","analyzing","generative","recognition","developing","improvement","computational","shortcomings","providing","principled","orientation","rendering","perceptual","convolutional","synthesizing","outperform","algorithms","variation","explicitly","fundamental","framework","discriminative","successes","extraordinary","previously","theoretical","empirical","assumptions","algorithm","foundations","appraisal","expressed","anomalies","designers","hypothesis","specifically","annotation","demonstrate","approximate","intractable","measuring","uncertain","strategies","convergence","selection","boundaries","considerably","empirically","adversarial","annotations","wikipedia","classifier","typically","ambiguity","resources","instances","supervised","necessary","dictionary","including","statistics","differences","evaluating","disambiguation","automatically","specially","ubiquitous","experiments","components","exploration","interoperability","fingerprint","resolution","complementary","reflection","performance","acquisition","involving","detection","particular","facilitate","community","grayscale","resistant","technique","frustrated","techniques","propagation","architecture","estimating","multiclass","classification","particularly","modifying","generalize","conditions","functions","minimization","robustness","inherently","alternate","properties","widespread","potential","artificial","probability","intelligence","contextual","clustering","dimensional","mentioned","spatiotemporal","associated","organizing","perspective","approximation","computing","numerical","corresponding","visualization","application","similarly","nonparametric","classical","interpret","continuous","expression","hierarchical","relationship","locations","variations","benchmark","nontrivial","measurements","attention","attracted","significant","furthermore","parameter","databases","implicitly","appearance","structure","automatic","evaluated","objectives","adaptation","transferred","disentangles","demonstrates","assumption","influence","satisfied","disentangled","unsupervised","individual","represent","introduce","characterize","ambiguous","discussions","occurrence","contained","compressed","subgraphs","analysing","occurring","relations","molecules","fragments","extensive","interested","proportional","outperforms","dependencies","companies","concordance","nonlinear","disclosed","regression","therefore","extremely","collected","iteration","factoring","alternating","factorization","procedure","separation","constraints","simulations","formulate","iteratively","fluorescence","complexity","promoting","important","optimization","selecting","regularization","incorporated","suppression","feasibility","consistent","observations","distributive", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	distributive
# 	simulators
# 	circularity
# 	varepsilon
# 	unmeasured
# 	staleness
# 	straggler
# 	concordant
# 	unobservable
# 	representer
# 	connectome
# 	underdetermined
# 	faithfulness
# 	reparametrization
# 	unintentionally
# 	semiparametric
# 	contractions
# 	regressions
# 	factorisation
# 	sparsification
# Some words which never appear in Statistics papers:
# 	explosive
# 	navigation
# 	pedestrian
# 	awareness
# 	extraordinary
# 	appraisal
# 	designers
# 	interoperability
# 	reflection
# 	grayscale
# 	frustrated
# 	fuzzification
# 	defuzzification
# 	monocular
# 	mountains
# 	inversely
# 	politicians
# 	affiliated
# 	inherited
# 	attenuation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.103758651727242e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
